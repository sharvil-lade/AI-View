# %% [markdown]
# # TRIBE v2 Demo: Predicting Brain Responses to Naturalistic Stimuli
#
# [TRIBE v2](https://github.com/facebookresearch/tribev2) is a deep multimodal brain encoding model that predicts **fMRI brain responses** to naturalistic stimuli — video, audio, and text.
#
# It combines state-of-the-art feature extractors — **LLaMA 3.2** (text), **V-JEPA2** (video), and **Wav2Vec-BERT** (audio) — into a unified Transformer that maps multimodal representations onto the cortical surface (**fsaverage5**, ~20k vertices).
#
# In this notebook, we will:
# 1. Load a pretrained TRIBE v2 model from HuggingFace
# 2. Predict brain responses to a **video** clip
# 3. Predict brain responses to **audio** generated from text
# 4. Visualize the predicted activity on a 3D brain surface

# %% [markdown]
# ## Setup (for Colab users)
#
# 1. Activate the GPU (Menu > Runtime > Change runtime)
# 2. Run the command below
# 3. Restart your environment for the new packages to be taken into account

# %%
# exca 0.5.26 removed exca.steps.base.NoValue, which neuralset 0.0.2 still imports
# -> pin exca==0.5.25 (satisfies neuralset's exca>=0.5.20). tribev2 pins numpy==2.2.6 itself.
# !pip install "tribev2[plotting] @ git+https://github.com/facebookresearch/tribev2.git" "exca==0.5.25"

# Restart runtime so the new packages load. Re-run from the next cell after restart.
import os
os._exit(0)
# Out:
# Collecting tribev2@ git+https://github.com/facebookresearch/tribev2.git (from tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git)
#   Cloning https://github.com/facebookresearch/tribev2.git to /tmp/pip-install-g59ui_4k/tribev2_0cbbb39b18f74a38b53988c32442e9c2
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/tribev2.git /tmp/pip-install-g59ui_4k/tribev2_0cbbb39b18f74a38b53988c32442e9c2
#   Resolved https://github.com/facebookresearch/tribev2.git to commit 34f52344e5ba96660fac877393e1954e399d3ef3
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: exca==0.5.25 in /usr/local/lib/python3.12/dist-packages (0.5.25)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.12/dist-packages (from exca==0.5.25) (2.2.6)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.12/dist-packages (from exca==0.5.25) (6.0.3)
# Requirement already satisfied: pydantic>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from exca==0.5.25) (2.12.3)
# Requirement already satisfied: submitit>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from exca==0.5.25) (1.5.4)
# Requirement already satisfied: orjson in /usr/local/lib/python3.12/dist-packages (from exca==0.5.25) (3.11.9)
# Requirement already satisfied: neuralset==0.0.2 in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.0.2)
# Requirement already satisfied: neuraltrain==0.0.2 in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.0.2)
# Requirement already satisfied: torch<2.7,>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2.6.0)
# Requirement already satisfied: torchvision<0.22,>=0.20 in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.21.0)
# Requirement already satisfied: x_transformers==1.27.20 in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.27.20)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.8.2)
# Requirement already satisfied: moviepy>=2.2.1 in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2.2.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.17.0)
# Requirement already satisfied: gtts in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2.2.4)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.0.9)
# Requirement already satisfied: spacy in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (3.8.14)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.13.1)
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (24.1.2)
# Requirement already satisfied: Levenshtein in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.27.3)
# Requirement already satisfied: julius in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.2.8)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (5.9.0)
# Requirement already satisfied: pandas>=2.2.2 in /usr/local/lib/python3.12/dist-packages (from neuralset==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2.2.2)
# Requirement already satisfied: pyarrow>=17.0.0 in /usr/local/lib/python3.12/dist-packages (from neuralset==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (18.1.0)
# Requirement already satisfied: mne>=1.10.2 in /usr/local/lib/python3.12/dist-packages (from neuralset==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.12.1)
# Requirement already satisfied: mne_bids>=0.16 in /usr/local/lib/python3.12/dist-packages (from neuralset==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.19.0)
# Requirement already satisfied: pyprep>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from neuralset==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.6.0)
# Requirement already satisfied: scikit-learn>=0.21.2 in /usr/local/lib/python3.12/dist-packages (from neuralset==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.6.1)
# Requirement already satisfied: nibabel>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from neuralset==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (5.4.2)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from neuralset==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (4.67.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from neuralset==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (26.2)
# Requirement already satisfied: polars>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from neuralset==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.35.2)
# Requirement already satisfied: ujson in /usr/local/lib/python3.12/dist-packages (from neuralset==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (5.12.1)
# Requirement already satisfied: torchmetrics>=1.1.2 in /usr/local/lib/python3.12/dist-packages (from neuraltrain==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.9.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.13.2)
# Requirement already satisfied: colorcet in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (3.2.1)
# Requirement already satisfied: nilearn in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.13.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.17.1)
# Requirement already satisfied: pyvista in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.48.4)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.25.2)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /usr/local/lib/python3.12/dist-packages (from moviepy>=2.2.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (5.3.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.12/dist-packages (from moviepy>=2.2.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2.37.3)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from moviepy>=2.2.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.6.0)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.12/dist-packages (from moviepy>=2.2.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.1.12)
# Requirement already satisfied: python-dotenv>=0.10 in /usr/local/lib/python3.12/dist-packages (from moviepy>=2.2.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.2.2)
# Requirement already satisfied: pillow<12.0,>=9.2.0 in /usr/local/lib/python3.12/dist-packages (from moviepy>=2.2.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (11.3.0)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.12/dist-packages (from nibabel>=5.1.0->neuralset==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->exca==0.5.25) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->exca==0.5.25) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->exca==0.5.25) (0.4.2)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from submitit>=1.5.1->exca==0.5.25) (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (3.29.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (3.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (75.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from gtts->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from gtts->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (8.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from gtts->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.28.1)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.25.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from Levenshtein->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (3.14.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from nilearn->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.5.3)
# Requirement already satisfied: cyclopts>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from pyvista->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (4.16.1)
# Requirement already satisfied: pooch in /usr/local/lib/python3.12/dist-packages (from pyvista->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.9.0)
# Requirement already satisfied: scooby>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from pyvista->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.11.2)
# Requirement already satisfied: vtk!=9.4.0 in /usr/local/lib/python3.12/dist-packages (from pyvista->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (9.6.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2026.4.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.5)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2.0.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /usr/local/lib/python3.12/dist-packages (from spacy->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from spacy->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from spacy->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.3.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.7.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (3.0)
# Requirement already satisfied: attrs>=23.1.0 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=4.0.0->pyvista->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (26.1.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=4.0.0->pyvista->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.18.0)
# Requirement already satisfied: rich-rst<3.0.0,>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=4.0.0->pyvista->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2.0.1)
# Requirement already satisfied: rich>=13.6.0 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=4.0.0->pyvista->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (13.9.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<2.7,>=2.5.1->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (3.0.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.2->neuralset==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.2->neuralset==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2026.2)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=1.0.0->neuralset==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.35.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch->pyvista->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (4.10.0)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.12/dist-packages (from pyprep>=0.4.3->neuralset==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (5.9.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->gtts->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->gtts->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21.2->neuralset==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (3.6.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.12->spacy->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.3.3)
# Requirement already satisfied: lightning-utilities>=0.15.3 in /usr/local/lib/python3.12/dist-packages (from torchmetrics>=1.1.2->neuraltrain==0.0.2->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.15.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (7.6.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.6.0->cyclopts>=4.0.0->pyvista->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.6.0->cyclopts>=4.0.0->pyvista->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2.20.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (2.2.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.6.0->cyclopts>=4.0.0->pyvista->tribev2@ git+https://github.com/facebookresearch/tribev2.git->tribev2[plotting]@ git+https://github.com/facebookresearch/tribev2.git) (0.1.2)

# %% [markdown]
# ## Loading the model
#
# We load TRIBE v2 model from [HuggingFace Hub](https://huggingface.co/facebook/tribev2). On the first run, this downloads the model checkpoint and config (~1 GB). Subsequent runs use the cached version.
#
# We also initialize a `PlotBrain` object for 3D brain surface visualization using the **fsaverage5** mesh.

# %%
from tribev2.demo_utils import TribeModel, download_file
from tribev2.plotting import PlotBrain
from pathlib import Path

CACHE_FOLDER = Path("./cache")
CACHE_FOLDER.mkdir(exist_ok=True)

model = TribeModel.from_pretrained(
    "facebook/tribev2",
    cache_folder=CACHE_FOLDER,
)
plotter = PlotBrain(mesh="fsaverage5")
# Out:
# /usr/local/lib/python3.12/dist-packages/neuralset/extractors/base.py:707: UserWarning: LabelEncoder: event_types has not been set, are you sure you want to apply this extractor to all events?
#   warnings.warn(
# 2026-06-06 12:44:49 - WARNING - neuralset.extractors.base:798 - Missing events will be encoded using the default all-zero value (for example, 0 or a zero vector/tensor), which may be indistinguishable from a valid class if that class is also mapped to zeros. Set treat_missing_as_separate_class=True to avoid this.
# WARNING:neuralset.extractors.base:Missing events will be encoded using the default all-zero value (for example, 0 or a zero vector/tensor), which may be indistinguishable from a valid class if that class is also mapped to zeros. Set treat_missing_as_separate_class=True to avoid this.
# /usr/local/lib/python3.12/dist-packages/neuralset/extractors/base.py:707: UserWarning: LabelEncoder: event_types has not been set, are you sure you want to apply this extractor to all events?
#   warnings.warn(
# 2026-06-06 12:44:51 - WARNING - neuralset.extractors.base:798 - Missing events will be encoded using the default all-zero value (for example, 0 or a zero vector/tensor), which may be indistinguishable from a valid class if that class is also mapped to zeros. Set treat_missing_as_separate_class=True to avoid this.
# WARNING:neuralset.extractors.base:Missing events will be encoded using the default all-zero value (for example, 0 or a zero vector/tensor), which may be indistinguishable from a valid class if that class is also mapped to zeros. Set treat_missing_as_separate_class=True to avoid this.
# INFO - Loading model from /root/.cache/huggingface/hub/models--facebook--tribev2/snapshots/f894e783020944dcd96e5568550afe2aa9743f9f/best.ckpt
# INFO:tribev2.demo_utils:Loading model from /root/.cache/huggingface/hub/models--facebook--tribev2/snapshots/f894e783020944dcd96e5568550afe2aa9743f9f/best.ckpt
# /usr/local/lib/python3.12/dist-packages/x_transformers/x_transformers.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /usr/local/lib/python3.12/dist-packages/x_transformers/x_transformers.py:461: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)

# %% [markdown]
# ## Predict brain responses to a video
#
# Given a video file, TRIBE v2 automatically:
# 1. **Extracts audio** from the video track
# 2. **Transcribes speech** into word-level events with timestamps using [**WhisperX**](https://github.com/m-bain/whisperx)
# 3. **Extracts visual features** (DINOv2 + V-JEPA2) and **audio features** (Wav2Vec-BERT) and **text features** (LLaMA 3.2)
# 4. **Predicts fMRI activity** at each time step (1 TR = 1 second) across the cortical surface
#
# Below, we download a sample video ([Sintel trailer](https://durian.blender.org/)), build an events dataframe, and run the model.

# %%
# Upload your video via the Files panel -> /content/video.mp4
video_path = Path("/content/video.mp4")
assert video_path.exists(), f"{video_path} not found — upload video.mp4 via the Files panel first."

df = model.get_events_dataframe(video_path=video_path)
display(df.head(8)[["type", "start", "duration", "filepath", "text", "context"]])
# Out:
# Extract audio from video events: 100%|██████████| 1/1 [00:00<00:00, 2487.72it/s]
# /usr/local/lib/python3.12/dist-packages/neuralset/events/transforms/audio.py:56: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([events, pd.DataFrame(events_to_add)], ignore_index=True)
# /usr/local/lib/python3.12/dist-packages/neuralset/events/utils.py:134: UserWarning: The events dataframe contains an `Index` column. This is dangerous, please add drop=True in calls to df.reset_index(). Dropping it automatically.
#   warnings.warn(msg)
# Extracting words from audio: 100%|██████████| 1/1 [01:01<00:00, 61.02s/it]
# /usr/local/lib/python3.12/dist-packages/neuralset/events/utils.py:134: UserWarning: The events dataframe contains an `Index` column. This is dangerous, please add drop=True in calls to df.reset_index(). Dropping it automatically.
#   warnings.warn(msg)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Add context to words: 100%|██████████| 171/171 [00:00<00:00, 52924.00it/s]
#        type     start   duration            filepath  \
# 0     Audio  0.000000  74.870000  /content/video.wav
# 1     Video  0.000000  74.870000  /content/video.mp4
# 2  Sentence  0.550999   1.101002                 NaN
# 3      Text  0.551000  69.759000                 NaN
# 4      Word  0.551000   0.341000                 NaN
# 5      Word  0.912000   0.740000                 NaN
# 6  Sentence  1.711999   4.543002                 NaN
# 7      Word  1.712000   0.180000                 NaN
#
#                                                 text           context
# 0                                                NaN
# 1                                                NaN
# 2                                       10 crores?.
# 3  10 crores?. What kind of scam is this?. No, it...
# 4                                                 10                10
# 5                                            crores?        10 crores?
# 6                       What kind of scam is this?.
# 7                                               What  10 crores?. What

# %% [markdown]
# ### Run the model
#
# We feed the events dataframe to `model.predict()`, which extracts features for each modality, runs them through the Transformer, and returns predicted brain activity.
#
# NOTE: you will have to request access to the Llama-3.2 model using your HuggingFace account.
#
# The output `preds` has shape `(n_timesteps, n_vertices)` — one prediction per second of stimulus, with ~20k cortical vertices. The `segments` list contains the corresponding time segments with their associated events.

# %%
# HF login via Colab secret HF_TOKEN (toggle "Notebook access" ON in the Secrets panel).
# LLaMA 3.2 is gated — request access at https://huggingface.co/meta-llama/Llama-3.2-1B
from google.colab import userdata
from huggingface_hub import login
login(userdata.get("HF_TOKEN"))

preds, segments = model.predict(events=df)
print(f"Predictions shape: {preds.shape}  (n_timesteps, n_vertices)")

# %% [markdown]
# ### Visualize predictions on the brain surface
#
# We plot the predicted fMRI activity for the first 15 time steps on the fsaverage5 cortical mesh. Each panel shows one second of predicted activity, with the corresponding stimulus frame displayed below. Predictions are offset by 5 seconds in the past, in order to compensate for the hemodynamic lag.
#
# We see that as the image appears on the screen, the visual cortex lights up (t=4s), followed by the language network when the character starts to speak (t=12s).

# %%
n_timesteps = preds.shape[0]
fig = plotter.plot_timesteps(preds[:n_timesteps], segments=segments[:n_timesteps], cmap="fire", norm_percentile=99, vmin=.6, alpha_cmap=(0, .2), show_stimuli=True)

# %% [markdown]
# ## Predict brain responses to text (via text-to-speech)
#
# TRIBE v2 can also predict brain responses to **text** input. Since the model was trained on naturalistic audio/video stimuli, text is first converted to speech using Google Text-to-Speech (gTTS), then transcribed back to obtain precise word-level timings.
#
# Below, we use a passage from Shakespeare's *Hamlet* as input.

# %%
text = """
To be or not to be, that is the question.
Whether 'tis nobler in the mind to suffer
The slings and arrows of outrageous fortune,
Or to take arms against a sea of troubles
And by opposing end them. To die, to sleep,
No more; and by a sleep to say we end
The heartache and the thousand natural shocks
"""

text_path = CACHE_FOLDER / "shakespeare.txt"
text_path.write_text(text)

df = model.get_events_dataframe(text_path=text_path)
display(df.head(8)[["type", "start", "duration", "filepath", "text", "context"]])

# %% [markdown]
# ### Run the model
#
# Same as before — we pass the events dataframe to `model.predict()` to get brain activity predictions for each time step.

# %%
preds, segments = model.predict(events=df)
print(f"Predictions shape: {preds.shape}  (n_timesteps, n_vertices)")

# %% [markdown]
# ### Visualize predictions on the brain surface
#
# Again, we visualize the first 15 seconds of predicted activity. For audio-only stimuli, the stimulus display shows the spoken words at each time step.

# %%
n_timesteps = 15
fig = plotter.plot_timesteps(preds[:n_timesteps], segments=segments[:n_timesteps], cmap="fire", norm_percentile=99, vmin=.6, alpha_cmap=(0, .2), show_stimuli=True)
